# %% [raw]
# ---
# title: "teaching Generative AI"
# author: "Barry Quinn CStat"
# format:
#   revealjs:
#     preview-links: auto
#     theme: [default,mycssblend.css]
# editor: visual
# ---

# %% [markdown]
# ```{css}
# #| echo:false
# .bg_digital {
#   position: relative;
#   z-index: 1;
# }
#
# .bg_digital::before {
#       content: "";
#       background-image: url('img/digital-transformation.jpg');
#       background-size: cover;
#       position: absolute;
#       top: 0px;
#       right: 0px;
#       bottom: 0px;
#       left: 0px;
#       opacity: 0.4;
#       z-index: -1;
# }
# ```
#
#
#
#
# ## Why teach AI in a Business School {.small}
#
# -   Finance industry has long been an early information technology.
#
# -   Although finance is a social science, many parts of the finance industry are fundamentally quantitative and increasingly algorithmic.
#
# -   AI is a broad term, but AI safety is an emerging business practice.
#
# -   AI, unlike previous technologies, is the first tool in history:
#
#     -   that can "make decision" by itself
#
#     -   that can create "new ideas" by itself
#
# [Yuval Noah Harari on AI Safety](https://open.spotify.com/episode/4cDwZmBR7pbGsEM4dVmCl2?si=4b5169a852604225){preview-link="true"}
#
# ## Learning objective
#
# -   Understanding algorithmic risk and control
#
# -   How to be a responsible early adopter of an emerging technology
#
# -   How to use *AI tooling* to improve productivity
#
# -   How to be intellectually humble, curious, and critical
#
# -   Be industry relevant
#
# ## Learning outcomes
#
# -   Develop principled mathematical know-how for algorithmic control
#
# -   Understand the statistical principles of Generative AI
#
# -   Successful apply Gen AI to a industry relevant problem statement
#
# -   Actively learn how to build and deploy a zero-shot AI inference machine
#
# ## Teaching
#
# ::: columns
# ::: {.column width="50%"}
# -   Building empirical *grit* (break it to learn it)
#
# -   Embedding real-world practice
#
# -   Open science analytics
#
# -   Culture of curiosity (not competition)
#
# -   Literate programming ([Knuth (1992)](https://www-cs-faculty.stanford.edu/~knuth/lp.html))
# :::
#
# ::: {.column width="50%"}
# -   Open source software
# -   ☁️ computing
# -   Version control
# -   Quarto computational notebook for reproducibility
# -   Simulation (fake it then break it before you make it)
# :::
# :::
#
# ## Teaching environment
